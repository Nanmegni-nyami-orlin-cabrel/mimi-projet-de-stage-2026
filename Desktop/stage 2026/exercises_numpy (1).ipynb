# %%
Sur le dataset choisi, tu réponds à ces cinq questions uniquement avec Pandas, sans aucune visualisation encore. Qui a la meilleure moyenne générale ? Est-ce que le genre a un impact sur les résultats en maths ? Quel groupe ethnique réussit le mieux en lecture ? Combien d'élèves ont une note en dessous de 50 dans au moins une matière ? Quel est l'impact du niveau d'éducation des parents sur les résultats ? Pour chaque question, tu affiches le résultat et tu l'interprètes en une phrase.
LIVRABLES DU JOUR

+ Notebook NumPy avec les exercices du cours, poussé sur GitHub
+ Notebook Pandas avec le dataset nettoyé et les cinq questions répondues avec interprétation
+ Commit GitHub propre avec un message descriptif
